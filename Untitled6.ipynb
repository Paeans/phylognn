# %%
from gene_graph_dataset import G3MedianDataset

# %%
dataset = G3MedianDataset('dataset_g3m', 1000, 1000, graph_num = 10)
# Out:
# Generating...
# Fri Dec 24 14:15:09 2021 >> step: 0000, number: 000010, length: 001000
# Fri Dec 24 14:15:12 2021 >> step: 0001, number: 000010, length: 001000
# Fri Dec 24 14:15:16 2021 >> step: 0002, number: 000010, length: 001000
# Fri Dec 24 14:15:21 2021 >> step: 0003, number: 000010, length: 001000
# Fri Dec 24 14:15:28 2021 >> step: 0004, number: 000010, length: 001000
# Fri Dec 24 14:15:37 2021 >> step: 0005, number: 000010, length: 001000
# Fri Dec 24 14:15:48 2021 >> step: 0006, number: 000010, length: 001000
# Fri Dec 24 14:16:00 2021 >> step: 0007, number: 000010, length: 001000
# Fri Dec 24 14:16:15 2021 >> step: 0008, number: 000010, length: 001000
# Fri Dec 24 14:16:31 2021 >> step: 0009, number: 000010, length: 001000
# Fri Dec 24 14:16:48 2021 >> step: 0010, number: 000010, length: 001000
# Fri Dec 24 14:17:08 2021 >> step: 0011, number: 000010, length: 001000
# Fri Dec 24 14:17:29 2021 >> step: 0012, number: 000010, length: 001000
# ...
